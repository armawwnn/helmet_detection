# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !mkdir {HOME}/model
# %cd {HOME}/model
# !unzip /content/gdrive/MyDrive/run.zip
# Out:
# mkdir: cannot create directory ‘{HOME}/model’: No such file or directory
# [Errno 2] No such file or directory: '{HOME}/model'
# /content
# Archive:  /content/gdrive/MyDrive/run.zip
#    creating: detect/
#    creating: detect/predict/
#    creating: detect/train/
#    creating: detect/train2/
#    creating: detect/train3/
#    creating: detect/train4/
#    creating: detect/train5/
#    creating: detect/train6/
#    creating: detect/train4/weights/
#   inflating: detect/train4/events.out.tfevents.1713191361.6e107c23e4e3.5243.0
#   inflating: detect/train4/args.yaml
#    creating: detect/train3/weights/
#   inflating: detect/train3/events.out.tfevents.1713190870.6e107c23e4e3.3121.0
#   inflating: detect/train3/labels_correlogram.jpg
#   inflating: detect/train3/train_batch1.jpg
#   inflating: detect/train3/labels.jpg
#   inflating: detect/train3/train_batch0.jpg
#   inflating: detect/train3/train_batch2.jpg
#   inflating: detect/train3/results.csv
# ...

# %%
# Pip install method (recommended)

# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.47 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 31.8/107.7 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model= conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# /content
# ...
# 100% 6.23M/6.23M [00:00<00:00, 86.1MB/s]
# Ultralytics YOLOv8.1.47 🚀 Python-3.10.12 torch-2.2.0+cpu CPU (Intel Xeon 2.00GHz)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# 100% 104k/104k [00:00<00:00, 112MB/s]
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 93.0ms
# Speed: 3.2ms preprocess, 93.0ms inference, 3401.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive
#  12105-Translation.gdoc				'سند بدون عنوان (17).gdoc'
#  992.gdoc					'سند بدون عنوان (18).gdoc'
#  ARMAN123					'سند بدون عنوان (19).gdoc'
#  arman.gsheet					'سند بدون عنوان (1).gdoc'
#  arman.xlsx					'سند بدون عنوان (20).gdoc'
#  avast						'سند بدون عنوان (21).gdoc'
# 'c2FkZWdoaS5hbGkuMTk5OUBnbWFpbC5jb20= (1).txt'	'سند بدون عنوان (22).gdoc'
# 'Colab Notebooks'				'سند بدون عنوان (23).gdoc'
#  config						'سند بدون عنوان (24).gdoc'
#  Countr.gsheet					'سند بدون عنوان (25).gdoc'
#  DOC-20221231-WA0001..pdf			'سند بدون عنوان (26).gdoc'
#  id_rsa						'سند بدون عنوان (27).gdoc'
#  id_rsa.pub					'سند بدون عنوان (28).gdoc'
#  IMG-20140930-WA0015.jpg			'سند بدون عنوان (29).gdoc'
# 'jjr-chnz-yjj - ۱ ژانویه ۲۰۲۳.gjam'		'سند بدون عنوان (2).gdoc'
#  Meell						'سند بدون عنوان (30).gdoc'
# 'My Drive'					'سند بدون عنوان (31).gdoc'
#  niama_ta					'سند بدون عنوان (32).gdoc'
#  pass						'سند بدون عنوان (33).gdoc'
#  run.zip					'سند بدون عنوان (34).gdoc'
# ...

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !unzip /content/gdrive/MyDrive/ds_helmet.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: dataset/train/labels/002031_jpg.rf.dca7488d63eeccaf3fe9d92f999eac24.txt
#   inflating: __MACOSX/dataset/train/labels/._002031_jpg.rf.dca7488d63eeccaf3fe9d92f999eac24.txt
#   inflating: dataset/train/labels/000524_jpg.rf.8bc7aba1f6a79f94e4a16e7a254ab9be.txt
#   inflating: __MACOSX/dataset/train/labels/._000524_jpg.rf.8bc7aba1f6a79f94e4a16e7a254ab9be.txt
#   inflating: dataset/train/labels/003920_jpg.rf.8d0096ae4e2fbecf4b80bede7a67f91e.txt
#   inflating: __MACOSX/dataset/train/labels/._003920_jpg.rf.8d0096ae4e2fbecf4b80bede7a67f91e.txt
#   inflating: dataset/train/labels/001537_jpg.rf.59d2fe8505faad9316bfd64b37c94cd1.txt
#   inflating: __MACOSX/dataset/train/labels/._001537_jpg.rf.59d2fe8505faad9316bfd64b37c94cd1.txt
#   inflating: dataset/train/labels/002398_jpg.rf.9feaac323f282d366209cf288e026f29.txt
#   inflating: __MACOSX/dataset/train/labels/._002398_jpg.rf.9feaac323f282d366209cf288e026f29.txt
# ...

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data=/content/datasets/dataset/data.yaml epochs=10 imgsz=800 bch=256 plots=True
# Out:
# /content
# Ultralytics YOLOv8.1.47 🚀 Python-3.10.12 torch-2.2.0+cpu CPU (Intel Xeon 2.00GHz)
# ...

# %%
import shutil
shutil.make_archive("/content/runs", 'zip', "/content/runs")
# Out:
# '/content/runs.zip'

# %%
# !cp /content/runs.zip /content/gdrive/MyDrive/

# %%
from IPython.display import Image

Image(filename="/content/detect/train6/results.png", width=1000)

# %%
from IPython.display import Image

Image(filename="/content/detect/train6/confusion_matrix.png", width=1000)

# %%
from IPython.display import Image

Image(filename="/content/detect/train6/val_batch0_pred.jpg", width=1000)
